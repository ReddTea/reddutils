# %%
import numpy as np
import matplotlib.pyplot as pl

import reddutils

# %%
x = np.sort(np.random.uniform(0,30,1000))
y = np.sin(x)

# %%
x1, y1 = reddutils.fold(x, y, per = 2*np.pi)

# %%
pl.plot(x, y, 'bo')

# %%
pl.plot(x1, y1, 'bo')
